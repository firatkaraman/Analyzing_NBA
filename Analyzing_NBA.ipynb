# %%
pip install plotly==5.11.0
# Out:
# Requirement already satisfied: plotly==5.11.0 in d:\anaconda\anaconda3\lib\site-packages (5.11.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: tenacity>=6.2.0 in d:\anaconda\anaconda3\lib\site-packages (from plotly==5.11.0) (8.0.1)

# %%
pip install "jupyterlab>=3" "ipywidgets>=7.6"
# Out:
# Requirement already satisfied: jupyterlab>=3 in d:\anaconda\anaconda3\lib\site-packages (3.4.4)
# Requirement already satisfied: ipywidgets>=7.6 in d:\anaconda\anaconda3\lib\site-packages (7.6.5)
# Requirement already satisfied: notebook<7 in d:\anaconda\anaconda3\lib\site-packages (from jupyterlab>=3) (6.4.12)
# Requirement already satisfied: packaging in d:\anaconda\anaconda3\lib\site-packages (from jupyterlab>=3) (21.3)
# Requirement already satisfied: ipython in d:\anaconda\anaconda3\lib\site-packages (from jupyterlab>=3) (7.31.1)
# Requirement already satisfied: jupyter-server~=1.16 in d:\anaconda\anaconda3\lib\site-packages (from jupyterlab>=3) (1.18.1)
# Requirement already satisfied: jinja2>=2.1 in d:\anaconda\anaconda3\lib\site-packages (from jupyterlab>=3) (2.11.3)
# Requirement already satisfied: nbclassic in d:\anaconda\anaconda3\lib\site-packages (from jupyterlab>=3) (0.3.5)
# Requirement already satisfied: jupyterlab-server~=2.10 in d:\anaconda\anaconda3\lib\site-packages (from jupyterlab>=3) (2.10.3)
# Requirement already satisfied: tornado>=6.1.0 in d:\anaconda\anaconda3\lib\site-packages (from jupyterlab>=3) (6.1)
# Requirement already satisfied: jupyter-core in d:\anaconda\anaconda3\lib\site-packages (from jupyterlab>=3) (4.11.1)
# Requirement already satisfied: nbformat>=4.2.0 in d:\anaconda\anaconda3\lib\site-packages (from ipywidgets>=7.6) (5.5.0)
# Requirement already satisfied: ipykernel>=4.5.1 in d:\anaconda\anaconda3\lib\site-packages (from ipywidgets>=7.6) (6.15.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in d:\anaconda\anaconda3\lib\site-packages (from ipywidgets>=7.6) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in d:\anaconda\anaconda3\lib\site-packages (from ipywidgets>=7.6) (1.0.0)
# Requirement already satisfied: traitlets>=4.3.1 in d:\anaconda\anaconda3\lib\site-packages (from ipywidgets>=7.6) (5.1.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in d:\anaconda\anaconda3\lib\site-packages (from ipywidgets>=7.6) (0.2.0)
# Requirement already satisfied: psutil in d:\anaconda\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6) (5.9.0)
# Requirement already satisfied: nest-asyncio in d:\anaconda\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6) (1.5.5)
# Requirement already satisfied: pyzmq>=17 in d:\anaconda\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6) (23.2.0)
# Requirement already satisfied: debugpy>=1.0 in d:\anaconda\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6) (1.5.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\anaconda\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6) (7.3.4)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\anaconda\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6) (0.1.6)
# Requirement already satisfied: setuptools>=18.5 in d:\anaconda\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (63.4.1)
# Requirement already satisfied: colorama in d:\anaconda\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (0.4.5)
# Requirement already satisfied: decorator in d:\anaconda\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\anaconda\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (3.0.20)
# Requirement already satisfied: backcall in d:\anaconda\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (0.2.0)
# Requirement already satisfied: pickleshare in d:\anaconda\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (0.18.1)
# Requirement already satisfied: pygments in d:\anaconda\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (2.11.2)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda\anaconda3\lib\site-packages (from jinja2>=2.1->jupyterlab>=3) (2.0.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in d:\anaconda\anaconda3\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3) (3.5.0)
# Requirement already satisfied: Send2Trash in d:\anaconda\anaconda3\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3) (1.8.0)
# Requirement already satisfied: prometheus-client in d:\anaconda\anaconda3\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3) (0.14.1)
# Requirement already satisfied: argon2-cffi in d:\anaconda\anaconda3\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3) (21.3.0)
# Requirement already satisfied: pywinpty in d:\anaconda\anaconda3\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3) (2.0.2)
# Requirement already satisfied: nbconvert>=6.4.4 in d:\anaconda\anaconda3\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3) (6.4.4)
# Requirement already satisfied: websocket-client in d:\anaconda\anaconda3\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3) (0.58.0)
# Requirement already satisfied: terminado>=0.8.3 in d:\anaconda\anaconda3\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3) (0.13.1)
# Requirement already satisfied: pywin32>=1.0 in d:\anaconda\anaconda3\lib\site-packages (from jupyter-core->jupyterlab>=3) (302)
# Requirement already satisfied: entrypoints>=0.2.2 in d:\anaconda\anaconda3\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab>=3) (0.4)
# Requirement already satisfied: json5 in d:\anaconda\anaconda3\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab>=3) (0.9.6)
# Requirement already satisfied: jsonschema>=3.0.1 in d:\anaconda\anaconda3\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab>=3) (4.16.0)
# Requirement already satisfied: requests in d:\anaconda\anaconda3\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab>=3) (2.28.1)
# Requirement already satisfied: babel in d:\anaconda\anaconda3\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab>=3) (2.9.1)
# Requirement already satisfied: fastjsonschema in d:\anaconda\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.6) (2.16.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda\anaconda3\lib\site-packages (from packaging->jupyterlab>=3) (3.0.9)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.16->jupyterlab>=3) (1.2.0)
# Requirement already satisfied: idna>=2.8 in d:\anaconda\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.16->jupyterlab>=3) (3.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\anaconda\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyterlab>=3) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\anaconda\anaconda3\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in d:\anaconda\anaconda3\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3) (21.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6) (2.8.2)
# Requirement already satisfied: testpath in d:\anaconda\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in d:\anaconda\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in d:\anaconda\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3) (0.5.13)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\anaconda\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in d:\anaconda\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3) (0.1.2)
# Requirement already satisfied: bleach in d:\anaconda\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3) (4.1.0)
# Requirement already satisfied: defusedxml in d:\anaconda\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3) (0.7.1)
# Requirement already satisfied: wcwidth in d:\anaconda\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab>=3) (0.2.5)
# Requirement already satisfied: argon2-cffi-bindings in d:\anaconda\anaconda3\lib\site-packages (from argon2-cffi->jupyter-server~=1.16->jupyterlab>=3) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in d:\anaconda\anaconda3\lib\site-packages (from babel->jupyterlab-server~=2.10->jupyterlab>=3) (2022.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\anaconda3\lib\site-packages (from requests->jupyterlab-server~=2.10->jupyterlab>=3) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\anaconda3\lib\site-packages (from requests->jupyterlab-server~=2.10->jupyterlab>=3) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\anaconda\anaconda3\lib\site-packages (from requests->jupyterlab-server~=2.10->jupyterlab>=3) (2.0.4)
# Requirement already satisfied: six in d:\anaconda\anaconda3\lib\site-packages (from websocket-client->jupyter-server~=1.16->jupyterlab>=3) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in d:\anaconda\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.16->jupyterlab>=3) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3) (2.3.1)
# Requirement already satisfied: webencodings in d:\anaconda\anaconda3\lib\site-packages (from bleach->nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3) (0.5.1)
# Requirement already satisfied: pycparser in d:\anaconda\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.16->jupyterlab>=3) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "notebook>=5.3" "ipywidgets>=7.5"
# Out:
# Requirement already satisfied: notebook>=5.3 in d:\anaconda\anaconda3\lib\site-packages (6.4.12)
# Requirement already satisfied: ipywidgets>=7.5 in d:\anaconda\anaconda3\lib\site-packages (7.6.5)
# Requirement already satisfied: ipykernel in d:\anaconda\anaconda3\lib\site-packages (from notebook>=5.3) (6.15.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in d:\anaconda\anaconda3\lib\site-packages (from notebook>=5.3) (1.8.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in d:\anaconda\anaconda3\lib\site-packages (from notebook>=5.3) (4.11.1)
# Requirement already satisfied: nest-asyncio>=1.5 in d:\anaconda\anaconda3\lib\site-packages (from notebook>=5.3) (1.5.5)
# Requirement already satisfied: prometheus-client in d:\anaconda\anaconda3\lib\site-packages (from notebook>=5.3) (0.14.1)
# Requirement already satisfied: tornado>=6.1 in d:\anaconda\anaconda3\lib\site-packages (from notebook>=5.3) (6.1)
# Requirement already satisfied: traitlets>=4.2.1 in d:\anaconda\anaconda3\lib\site-packages (from notebook>=5.3) (5.1.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in d:\anaconda\anaconda3\lib\site-packages (from notebook>=5.3) (7.3.4)
# Requirement already satisfied: ipython-genutils in d:\anaconda\anaconda3\lib\site-packages (from notebook>=5.3) (0.2.0)
# Requirement already satisfied: terminado>=0.8.3 in d:\anaconda\anaconda3\lib\site-packages (from notebook>=5.3) (0.13.1)
# Requirement already satisfied: pyzmq>=17 in d:\anaconda\anaconda3\lib\site-packages (from notebook>=5.3) (23.2.0)
# Requirement already satisfied: nbconvert>=5 in d:\anaconda\anaconda3\lib\site-packages (from notebook>=5.3) (6.4.4)
# Requirement already satisfied: nbformat in d:\anaconda\anaconda3\lib\site-packages (from notebook>=5.3) (5.5.0)
# Requirement already satisfied: argon2-cffi in d:\anaconda\anaconda3\lib\site-packages (from notebook>=5.3) (21.3.0)
# Requirement already satisfied: jinja2 in d:\anaconda\anaconda3\lib\site-packages (from notebook>=5.3) (2.11.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in d:\anaconda\anaconda3\lib\site-packages (from ipywidgets>=7.5) (1.0.0)
# Requirement already satisfied: ipython>=4.0.0 in d:\anaconda\anaconda3\lib\site-packages (from ipywidgets>=7.5) (7.31.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in d:\anaconda\anaconda3\lib\site-packages (from ipywidgets>=7.5) (3.5.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\anaconda\anaconda3\lib\site-packages (from ipykernel->notebook>=5.3) (0.1.6)
# Requirement already satisfied: debugpy>=1.0 in d:\anaconda\anaconda3\lib\site-packages (from ipykernel->notebook>=5.3) (1.5.1)
# Requirement already satisfied: psutil in d:\anaconda\anaconda3\lib\site-packages (from ipykernel->notebook>=5.3) (5.9.0)
# Requirement already satisfied: packaging in d:\anaconda\anaconda3\lib\site-packages (from ipykernel->notebook>=5.3) (21.3)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in d:\anaconda\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (63.4.1)
# Requirement already satisfied: pickleshare in d:\anaconda\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (0.7.5)
# Requirement already satisfied: colorama in d:\anaconda\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (0.4.5)
# Requirement already satisfied: pygments in d:\anaconda\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (2.11.2)
# Requirement already satisfied: decorator in d:\anaconda\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (5.1.1)
# Requirement already satisfied: backcall in d:\anaconda\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\anaconda\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (3.0.20)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=5.3) (2.8.2)
# Requirement already satisfied: entrypoints in d:\anaconda\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=5.3) (0.4)
# Requirement already satisfied: pywin32>=1.0 in d:\anaconda\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook>=5.3) (302)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.3) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in d:\anaconda\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.3) (0.1.2)
# Requirement already satisfied: defusedxml in d:\anaconda\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.3) (0.7.1)
# Requirement already satisfied: testpath in d:\anaconda\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.3) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\anaconda\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.3) (1.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in d:\anaconda\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.3) (0.5.13)
# Requirement already satisfied: mistune<2,>=0.8.1 in d:\anaconda\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.3) (0.8.4)
# Requirement already satisfied: bleach in d:\anaconda\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.3) (4.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda\anaconda3\lib\site-packages (from jinja2->notebook>=5.3) (2.0.1)
# Requirement already satisfied: fastjsonschema in d:\anaconda\anaconda3\lib\site-packages (from nbformat->notebook>=5.3) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in d:\anaconda\anaconda3\lib\site-packages (from nbformat->notebook>=5.3) (4.16.0)
# Requirement already satisfied: pywinpty>=1.1.0 in d:\anaconda\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=5.3) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in d:\anaconda\anaconda3\lib\site-packages (from argon2-cffi->notebook>=5.3) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\anaconda\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\anaconda\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=5.3) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in d:\anaconda\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=5.3) (21.4.0)
# Requirement already satisfied: wcwidth in d:\anaconda\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5) (0.2.5)
# Requirement already satisfied: six>=1.5 in d:\anaconda\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=5.3.4->notebook>=5.3) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in d:\anaconda\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=5.3) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=5.3) (2.3.1)
# Requirement already satisfied: webencodings in d:\anaconda\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=5.3) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda\anaconda3\lib\site-packages (from packaging->ipykernel->notebook>=5.3) (3.0.9)
# Requirement already satisfied: pycparser in d:\anaconda\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=5.3) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd 
import plotly.express as px
import plotly.graph_objects as go
pd.set_option('display.max_columns', None)

data = pd.read_excel('nba_player_data.xlsx')

# %%
data.sample(10)
# Out:
#          Year       Season_type  PLAYER_ID  RANK            PLAYER TEAM  GP  \
# 1354  2013-14          Playoffs     203488   185      Mike Muscala  ATL   2
# 2704  2015-16          Playoffs     203613   166  Jonathon Simmons  SAS   3
# 2610  2015-16          Playoffs    1626167    72      Myles Turner  IND   7
# 1254  2013-14          Playoffs     101150    96      Lou Williams  ATL   7
# 1376  2014-15  Regular%20Season     200752    15          Rudy Gay  SAC  68
# 5856  2020-21  Regular%20Season     204456   165    T.J. McConnell  IND  69
# 5810  2020-21  Regular%20Season     201988   119       Patty Mills  SAS  68
# 3097  2016-17  Regular%20Season     203902   345    Semaj Christon  OKC  64
# 3294  2016-17          Playoffs     101162    55     Marcin Gortat  WAS  13
# 3583  2017-18  Regular%20Season     202322   129         John Wall  WAS  41
#
#        MIN  FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  \
# 1354     5    0     2   0.000     0     0    0.000    0    0   0.000     0
# 2704    26    4    10   0.400     2     3    0.667    1    2   0.500     3
# 2610   197   33    71   0.465     0     2    0.000    6    9   0.667    16
# 1254   133   19    50   0.380     5    16    0.313   15   16   0.938     0
# 1376  2408  508  1116   0.455    79   220    0.359  337  393   0.858    98
# 5856  1796  274   490   0.559    15    48    0.313   33   48   0.688    55
# 5810  1685  252   611   0.412   161   429    0.375   71   78   0.910    18
# 3097   973   77   223   0.345    12    63    0.190   17   31   0.548    19
# 3294   409   47    93   0.505     0     0    0.000   11   18   0.611    52
# 3583  1410  280   667   0.420    62   167    0.371  175  241   0.726    22
#
#       DREB  REB  AST  STL  BLK  TOV   PF   PTS   EFF  AST_TOV  STL_TOV
# 1354     0    0    0    0    0    0    0     0    -2     0.00     0.00
# 2704     1    4    2    2    0    1    4    11    11     2.00     2.00
# 2610    29   45    3    2   23   12   24    72    92     0.25     0.17
# 1254    16   16    8    7    1   13   10    58    45     0.61     0.54
# 1376   301  399  250   71   41  183  157  1432  1346     1.37     0.39
# 5856   201  256  456  128   23  135  113   596  1093     3.38     0.95
# 5810    98  116  162   42    3   66   81   736   627     2.46     0.64
# 3097    68   87  130   28    7   43   79   183   232     3.02     0.65
# 3294    91  143   24    5   20   17   40   105   227     1.41     0.29
# 3583   128  150  393   57   45  158   80   797   831     2.49     0.36

# %%
data.head(10)
# Out:
#       Year       Season_type  PLAYER_ID  RANK             PLAYER TEAM  GP  \
# 0  2012-13  Regular%20Season     201142     1       Kevin Durant  OKC  81
# 1  2012-13  Regular%20Season        977     2        Kobe Bryant  LAL  78
# 2  2012-13  Regular%20Season       2544     3       LeBron James  MIA  76
# 3  2012-13  Regular%20Season     201935     4       James Harden  HOU  78
# 4  2012-13  Regular%20Season       2546     5    Carmelo Anthony  NYK  67
# 5  2012-13  Regular%20Season     201566     6  Russell Westbrook  OKC  82
# 6  2012-13  Regular%20Season     201939     7      Stephen Curry  GSW  78
# 7  2012-13  Regular%20Season     101145     8        Monta Ellis  MIL  82
# 8  2012-13  Regular%20Season     203081     9     Damian Lillard  POR  82
# 9  2012-13  Regular%20Season     200746    10  LaMarcus Aldridge  POR  74
#
#     MIN  FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  \
# 0  3119  731  1433   0.510   139   334    0.416  679  750   0.905    46   594
# 1  3013  738  1595   0.463   132   407    0.324  525  626   0.839    66   367
# 2  2877  765  1354   0.565   103   254    0.406  403  535   0.753    97   513
# 3  2985  585  1337   0.438   179   486    0.368  674  792   0.851    62   317
# 4  2482  669  1489   0.449   157   414    0.379  425  512   0.830   134   326
# 5  2861  673  1535   0.438    97   300    0.323  460  575   0.800   111   317
# 6  2983  626  1388   0.451   272   600    0.453  262  291   0.900    59   255
# 7  3076  597  1436   0.416    94   328    0.287  289  374   0.773    45   271
# 8  3167  553  1288   0.429   185   503    0.368  271  321   0.844    42   215
# 9  2790  638  1318   0.484     2    14    0.143  282  348   0.810   175   495
#
#    REB  AST  STL  BLK  TOV   PF   PTS   EFF  AST_TOV  STL_TOV
# 0  640  374  116  105  280  143  2280  2462     1.34     0.41
# 1  433  469  106   25  287  173  2133  1921     1.63     0.37
# 2  610  551  129   67  226  110  2036  2446     2.44     0.57
# 3  379  455  142   38  295  178  2023  1872     1.54     0.48
# 4  460  171   52   32  175  205  1920  1553     0.98     0.30
# 5  428  607  145   24  273  189  1903  1857     2.22     0.53
# 6  314  539  126   12  240  198  1786  1746     2.25     0.53
# 7  316  496  169   36  254  164  1577  1416     1.95     0.67
# 8  257  531   74   19  243  172  1562  1415     2.19     0.30
# 9  670  192   62   91  143  187  1560  1686     1.34     0.43

# %%
data.shape
# Out:
# (7293, 29)

# %% [markdown]
# <ul>
# <li>GP = Games Played</li>
# <li>MIN = Minutes Played</li>
# <li>PTS = Points</li>
# <li>FGM = Field Goals Made</li>
# <li>FGA = Field Goals Attempted</li>
# <li>FG% = Field Goals Percentage</li>
# <li>3PM = 3 Point Field Goals Made</li>
# <li>3PA = 3 Point Field Goals Attempted</li>
# <li>3P% = 3 Point Field Goals Percentage</li>
# <li>FTM = Free Throws Made</li>
# <li>FTA = Free Throws Attempted</li>
# <li>FT% = Free Throws Percentage</li>
# <li>OREB = Offensive Rebounds </li>
# <li>DREB = Defensive Rebounds</li>
# <li>REB = Rebounds</li>
# <li>AST = Assists</li>
# <li>STL = Steals</li>
# <li>BLK = Blocks</li>
# <li>TOV = Turnovers</li>
# <li>EFF = Player Efficiency</li>
# </ul>

# %% [markdown]
# # Data cleaning & analysis preparation

# %%
data.isna().sum()
# Out:
# Year           0
# Season_type    0
# PLAYER_ID      0
# RANK           0
# PLAYER         0
# TEAM           0
# GP             0
# MIN            0
# FGM            0
# FGA            0
# FG_PCT         0
# FG3M           0
# FG3A           0
# FG3_PCT        0
# FTM            0
# FTA            0
# FT_PCT         0
# OREB           0
# DREB           0
# REB            0
# AST            0
# STL            0
# BLK            0
# TOV            0
# PF             0
# PTS            0
# EFF            0
# AST_TOV        0
# STL_TOV        0
# dtype: int64

# %%
data.drop(columns=['RANK','EFF'], inplace = True)

# %%
data['Season_start_year'] =data['Year'].str[:4].astype(int)

# %%
data.TEAM.unique()
# Out:
# array(['OKC', 'LAL', 'MIA', 'HOU', 'NYK', 'GSW', 'MIL', 'POR', 'TOR',
#        'BKN', 'CHA', 'LAC', 'BOS', 'UTA', 'PHI', 'IND', 'SAS', 'ATL',
#        'CLE', 'NOH', 'DET', 'CHI', 'SAC', 'DAL', 'DEN', 'MEM', 'PHX',
#        'ORL', 'MIN', 'WAS', 'NOP'], dtype=object)

# %%
data.TEAM.nunique()
# Out:
# 31

# %%
data['TEAM'].replace(to_replace=['NOP','NOH'], value='NO', inplace=True)

# %%
data['Season_type'].replace('Regular%20Season', 'RS', inplace=True)

# %%
rs_df = data[data['Season_type']=='RS']
playoffs_df = data[data['Season_type']=='Playoffs']

# %%
playoffs_df
# Out:
#          Year Season_type  PLAYER_ID           PLAYER TEAM  GP  MIN  FGM  FGA  \
# 468   2012-13    Playoffs       2544     LeBron James  MIA  23  960  212  432
# 469   2012-13    Playoffs       2225      Tony Parker  SAS  21  765  167  365
# 470   2012-13    Playoffs       1495       Tim Duncan  SAS  21  735  151  321
# 471   2012-13    Playoffs     202331      Paul George  IND  19  780  119  277
# 472   2012-13    Playoffs       2548      Dwyane Wade  MIA  22  782  144  315
# ...       ...         ...        ...              ...  ...  ..  ...  ...  ...
# 7288  2021-22    Playoffs    1629006      Josh Okogie  MIN   1    2    0    0
# 7289  2021-22    Playoffs    1630556  Kessler Edwards  BKN   2    7    0    0
# 7290  2021-22    Playoffs    1630201    Malachi Flynn  TOR   6   36    0    7
# 7291  2021-22    Playoffs     202693  Markieff Morris  MIA   2    3    0    1
# 7292  2021-22    Playoffs     200794     Paul Millsap  PHI   1    6    0    0
#
#       FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  \
# 468    0.491    36    96    0.375  136  175   0.777    37   156  193  152
# 469    0.458    11    31    0.355   87  112   0.777    14    54   68  146
# 470    0.470     0     1    0.000   79   98   0.806    54   160  214   40
# 471    0.430    34   104    0.327   93  128   0.727    16   125  141   96
# 472    0.457     1     4    0.250   60   80   0.750    38    64  102  105
# ...      ...   ...   ...      ...  ...  ...     ...   ...   ...  ...  ...
# 7288   0.000     0     0    0.000    0    0   0.000     0     0    0    0
# 7289   0.000     0     0    0.000    0    0   0.000     0     0    0    1
# 7290   0.000     0     3    0.000    0    0   0.000     2     1    3    3
# 7291   0.000     0     0    0.000    0    0   0.000     0     1    1    0
# 7292   0.000     0     0    0.000    0    0   0.000     0     1    1    1
#
#       STL  BLK  TOV  PF  PTS  AST_TOV  STL_TOV  Season_start_year
# 468    41   18   70  43  596     2.17     0.59               2012
# 469    24    3   53  26  432     2.75     0.45               2012
# 470    18   34   42  53  381     0.95     0.43               2012
# 471    25    9   75  72  365     1.28     0.33               2012
# 472    38   23   58  45  349     1.81     0.66               2012
# ...   ...  ...  ...  ..  ...      ...      ...                ...
# 7288    0    0    0   0    0     0.00     0.00               2021
# 7289    1    0    1   3    0     1.00     1.00               2021
# 7290    1    0    1   6    0     3.00     1.00               2021
# 7291    0    0    1   2    0     0.00     0.00               2021
# 7292    0    0    0   1    0     0.00     0.00               2021
#
# [2145 rows x 28 columns]

# %%
data.columns
# Out:
# Index(['Year', 'Season_type', 'PLAYER_ID', 'PLAYER', 'TEAM', 'GP', 'MIN',
#        'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA',
#        'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS', 'AST_TOV', 'STL_TOV', 'Season_start_year'],
#       dtype='object')

# %%
total_cols = ['MIN','FGM','FGA','FG3M','FG3A','FTM','FTA','OREB','DREB','REB','AST','STL','BLK','TOV','PF','PTS']

# %% [markdown]
# # Which player stats are correlated with each other?

# %%
data.corr()
# Out:
#                    PLAYER_ID        GP       MIN       FGM       FGA  \
# PLAYER_ID           1.000000 -0.123665 -0.160812 -0.137554 -0.139728
# GP                 -0.123665  1.000000  0.905608  0.789848  0.796535
# MIN                -0.160812  0.905608  1.000000  0.935088  0.940743
# FGM                -0.137554  0.789848  0.935088  1.000000  0.989459
# FGA                -0.139728  0.796535  0.940743  0.989459  1.000000
# FG_PCT             -0.044359  0.217880  0.200545  0.212113  0.163044
# FG3M               -0.063209  0.617089  0.728095  0.713755  0.769594
# FG3A               -0.057878  0.639598  0.748195  0.730225  0.791253
# FG3_PCT             0.011896  0.203980  0.229306  0.214321  0.242616
# FTM                -0.144029  0.639904  0.802258  0.895489  0.888476
# FTA                -0.146257  0.660181  0.814633  0.898680  0.882753
# FT_PCT             -0.103690  0.345681  0.338089  0.313388  0.330974
# OREB               -0.118451  0.631183  0.651454  0.628332  0.559782
# DREB               -0.140710  0.776140  0.861414  0.849227  0.812269
# REB                -0.138966  0.760203  0.829745  0.814045  0.766880
# AST                -0.124454  0.636788  0.777331  0.788669  0.810013
# STL                -0.140518  0.787656  0.890922  0.830690  0.844514
# FG3_PCT                     0.108059
# FTM                        -0.060002
# FTA                        -0.070697
# FT_PCT                      0.003087
# OREB                       -0.083319
# DREB                       -0.044384
# REB                        -0.056926
# AST                        -0.026299
# STL                        -0.080368
# BLK                        -0.060701
# TOV                        -0.084464
# PF                         -0.095391
# PTS                        -0.033057
# AST_TOV                     0.102759
# STL_TOV                     0.044033
# Season_start_year           1.000000

# %%
data_per_min = data.groupby(['PLAYER','PLAYER_ID','Year'])[total_cols].sum().reset_index()
for col in data_per_min.columns[4:]:
    data_per_min[col] = data_per_min[col]/data_per_min['MIN']


data_per_min['FG%'] = data_per_min['FGM']/data_per_min['FGA']
data_per_min['3PT%'] = data_per_min['FG3M']/data_per_min['FG3A']
data_per_min['FT%'] = data_per_min['FTM']/data_per_min['FTA']
data_per_min['FG3A%'] = data_per_min['FG3A']/data_per_min['FGA']
data_per_min['PTS/FGA'] = data_per_min['PTS']/data_per_min['FGA']
data_per_min['FG3M/FGM'] = data_per_min['FG3M']/data_per_min['FGM']
data_per_min['FTA/FGA'] = data_per_min['FTA']/data_per_min['FGA']
data_per_min['TRU%'] = 0.5*data_per_min['PTS']/(data_per_min['FGA']+0.475*data_per_min['FTA'])
data_per_min['AST_TOV'] = data_per_min['AST']/data_per_min['TOV']

data_per_min = data_per_min[data_per_min['MIN']>=50]
data_per_min.drop(columns='PLAYER_ID', inplace=True)

fig = px.imshow(data_per_min.corr())
fig.show()

# %% [markdown]
# ## How are minutes played distributed?

# %%
fig = px.histogram(x=rs_df['MIN'], histnorm='percent')
fig.show()

# %%
fig = px.histogram(x=playoffs_df['MIN'], histnorm='percent')
fig.show()

# %%
fig = go.Figure()
fig.add_trace(go.Histogram(x=rs_df['MIN']/rs_df['GP'], histnorm='percent', name='RS', xbins={'start':0, 'end':46, 'size':1}))
fig.add_trace(go.Histogram(x=playoffs_df['MIN']/playoffs_df['GP'], histnorm='percent', name='Playoffs', xbins={'start':0, 'end':46, 'size':1}))

fig.update_layout(barmode='overlay')
fig.update_traces(opacity=0.5)
fig.show()

# %%
def hist_data(df=rs_df, min_MIN=0, min_GP=0):
    return df.loc[(df['MIN']>=min_MIN) & (df['GP']>=min_GP), 'MIN']/df.loc[(df['MIN']>=min_MIN) & (df['GP']>=min_GP), 'GP']

# %%
fig = go.Figure()
fig.add_trace(go.Histogram(x=hist_data(rs_df,50,5), histnorm='percent', name='RS', xbins={'start':0, 'end':46, 'size':1}))
fig.add_trace(go.Histogram(x=hist_data(playoffs_df,5,1), histnorm='percent', name='Playoffs', xbins={'start':0, 'end':46, 'size':1}))

fig.update_layout(barmode='overlay')
fig.update_traces(opacity=0.5)
fig.show()

# %%
((hist_data(rs_df,50,5)>=12)&(hist_data(rs_df,50,5)<=34)).mean()
# Out:
# 0.7495223943960942

# %%
((hist_data(playoffs_df,5,1)>=12)&(hist_data(playoffs_df,5,1)<=34)).mean()
# Out:
# 0.4944038929440389

# %%
def hist_data(df=rs_df, min_MIN=0, min_GP=0):
    return df.loc[(df['MIN']>=min_MIN) & (df['GP']>=min_GP), 'PTS']/df.loc[(df['MIN']>=min_MIN) & (df['GP']>=min_GP), 'GP']

fig = go.Figure()
fig.add_trace(go.Histogram(x=hist_data(rs_df,50,5), histnorm='percent', name='RS', xbins={'start':0, 'end':38, 'size':1}))
fig.add_trace(go.Histogram(x=hist_data(playoffs_df,5,1), histnorm='percent', name='Playoffs', xbins={'start':0, 'end':38, 'size':1}))

fig.update_layout(barmode='overlay')
fig.update_traces(opacity=0.5)
fig.show()

# %% [markdown]
# ## How has the game changed over the past 10 years?

# %%
change_df = data.groupby('Season_start_year')[total_cols].sum().reset_index()
change_df['POSS_est'] = change_df['FGA']-change_df['OREB']+change_df['TOV']+0.44*change_df['FTA']
change_df = change_df[list(change_df.columns[0:2])+['POSS_est']+list(change_df.columns[2:-1])]
change_df
# Out:
#    Season_start_year     MIN   POSS_est     FGM     FGA   FG3M   FG3A    FTM  \
# 0               2012  635884  248201.92   97235  215105  18808  52569  44125
# 1               2013  638373  254032.80   99251  218411  20480  56952  47219
# 2               2014  634546  253004.12   98251  219265  20724  59276  45098
# 3               2015  636391  258064.80  100351  222344  22524  63673  46516
# 4               2016  632482  258443.80  102147  223333  25408  71018  46806
# 5               2017  633425  260904.52  103729  225523  27530  76245  43721
# 6               2018  634231  268739.84  107374  233717  29817  84143  46671
# 7               2019  552262  234384.64   92997  202223  28032  78279  40949
# 8               2020  562518  235759.48   95849  205754  29549  80653  39624
# 9               2021  635572  264004.96  106569  231293  32733  92552  44740
#
#      FTA   OREB   DREB     REB    AST    STL    BLK    TOV     PF     PTS
# 0  58618  29237  81362  110599  57694  20376  13444  36542  52548  257403
# 1  62420  28669  83812  112481  57657  20156  12369  36826  54839  266201
# 2  60248  28566  85231  113797  57727  20261  12665  35796  53272  262324
# 3  61520  27426  87611  115037  58251  20562  13046  36078  53478  269742
# 4  60620  26470  87173  113643  59162  20143  12409  34908  52232  276508
# 5  57008  25397  88678  114075  60739  20181  12636  35695  52238  278709
# 6  60811  27128  91360  118488  64257  19940  12984  35394  55063  291236
# 7  52906  22802  79318  102120  55445  17368  11085  31685  47615  254975
# 8  50917  22918  80151  103069  57311  17491  11272  30520  45152  260871
# 9  57709  27052  89602  116654  64618  20006  12387  34372  52038  290611

# %%
change_df['FG%']= change_df['FGM']/change_df['FGA']
change_df['3PT%']= change_df['FG3M']/change_df['FG3A']
change_df['FT%']= change_df['FTM']/change_df['FTA']
change_df['AST%']= change_df['AST']/change_df['FGM']
change_df['FG3A%']= change_df['FG3A']/change_df['FGA']
change_df['PTS/FGA']= change_df['PTS']/change_df['FGA']
change_df['FG3M/FGM']= change_df['FG3M']/change_df['FGM']
change_df['FTA/FGA']= change_df['FTA']/change_df['FGA']
change_df['TRU%']= 0.5*change_df['PTS']/(change_df['FGA']+0.475*change_df['FTA'])
change_df['AST_TOV']= change_df['AST']/change_df['TOV']
change_df
# Out:
#    Season_start_year     MIN   POSS_est     FGM     FGA   FG3M   FG3A    FTM  \
# 0               2012  635884  248201.92   97235  215105  18808  52569  44125
# 8  0.567260  1.877818
# 9  0.561665  1.879960

# %% [markdown]
# #### yukardaki verilerde görüldüğü gibi yıllar geçtikçe POSS_est ve points verileri artış göstermektedir, oyunu hızının arttığını ve atılan başarı üçlükler ile oyun yapısının yıllar geçtikçe değiştiğini gözlemleyebiliriz

# %%
change_per48_df = change_df.copy()
for col in change_per48_df.columns[2:18]:
    change_per48_df[col] = change_per48_df[col]/change_per48_df['MIN']*48*5
    
change_per48_df.drop(columns='MIN', inplace=True)

fig = go.Figure()
for col in change_per48_df.columns[1:]:
    fig.add_trace(go.Scatter(x=change_per48_df['Season_start_year'],
                             y=change_per48_df[col], name=col))
    
fig.show()

# %%
change_per100_df = change_df.copy()


for col in change_per100_df.columns[3:18]:
    change_per100_df[col] = change_per100_df[col]/change_per100_df['POSS_est']*100
    
change_per100_df.drop(columns=['MIN','POSS_est'],inplace=True)
change_per100_df

fig = go.Figure()
for col in change_per100_df.columns[1:]:
    fig.add_trace(go.Scatter(x=change_per100_df['Season_start_year'],
                             y=change_per100_df[col], name=col))
    
fig.show()

# %% [markdown]
# ## Compare Regular season vs Playoofs

# %%
rs_change_df = rs_df.groupby('Season_start_year')[total_cols].sum().reset_index()
playoffs_change_df = playoffs_df.groupby('Season_start_year')[total_cols].sum().reset_index()

for i in [rs_change_df,playoffs_change_df]:
    i['POSS_est'] = i['FGA']-i['OREB']+i['TOV']+0.44*i['FTA']
    i['POSS_est_48'] =  (i['POSS_est']/i['MIN'])*48*5
    
    i['FG%']= i['FGM']/i['FGA']
    i['3PT%']= i['FG3M']/i['FG3A']
    i['FT%']= i['FTM']/i['FTA']
    i['AST%']= i['AST']/i['FGM']
    i['FG3A%']= i['FG3A']/i['FGA']
    i['PTS/FGA']= i['PTS']/i['FGA']
    i['FG3M/FGM']= i['FG3M']/i['FGM']
    i['FTA/FGA']= i['FTA']/i['FGA']
    i['TRU%']= 0.5*i['PTS']/(i['FGA']+0.475*i['FTA'])
    i['AST_TOV']= i['AST']/i['TOV']
    for col in total_cols:
        i[col] = 100*i[col]/i['POSS_est']
        
    i.drop(columns=['MIN','POSS_est'], inplace=True)
        
        
rs_change_df
# Out:
#    Season_start_year        FGM        FGA       FG3M       FG3A        FTM  \
# 0               2012  39.270953  86.735365   7.573088  21.109396  17.662937
# 1               2013  39.077222  85.994401   8.025279  22.311911  18.477433
# 2               2014  38.900086  86.650240   8.135183  23.240912  17.771371
# 3               2015  38.926558  86.096120   8.670900  24.515476  17.996886
# 4               2016  39.516445  86.434227   9.769173  27.323490  18.052073
# 5               2017  39.782703  86.439951  10.536996  29.127708  16.700692
# 6               2018  40.060963  86.993122  11.081358  31.213318  17.241016
# 7               2019  39.741774  86.378550  11.875237  33.176460  17.368831
# 8               2020  40.637565  87.183600  12.520406  34.156188  16.730698
# 9               2021  40.444286  87.713064  12.383811  35.022979  16.859678
#
#          FTA       OREB       DREB        REB        AST       STL       BLK  \
# 0  23.460955  11.812003  32.747162  44.559165  23.410189  8.250677  5.430183
# 1  24.441006  11.307161  32.985187  44.292348  22.799223  7.958311  4.883231
# 0               2012 -3.817 -1.272   0.959   5.262  10.247  10.479  -4.331
# 1               2013 -0.277 -0.301   6.989   7.352   9.133   8.175  -2.923
# 2               2014 -2.737  0.266  11.046  12.980   4.844   8.464   0.314
# 3               2015 -1.639  1.134  10.359  10.117   2.449   3.754   3.511
# 4               2016  0.316 -0.384  10.680   9.586   5.468   4.854  -2.594
# 5               2017 -1.036 -0.020   2.286   5.358   5.549   5.813  -3.358
# 6               2018 -4.331 -0.476   2.026   5.065  11.887   9.381   0.737
# 7               2019 -2.298 -1.639  10.056   9.412   8.292   6.206 -10.140
# 8               2020  0.620  1.445   1.480   2.218   6.434   5.243   4.155
# 9               2021 -3.008 -1.845   1.867   1.512   8.047   6.628  -6.394
#
#     DREB    REB     AST    STL     BLK     TOV      PF    PTS  POSS_est_48  \
# 0  1.607  0.033 -11.127 -7.870  -3.952  -3.323  14.087 -1.075       -2.632
# 1  0.343 -0.491  -6.880 -4.594  -4.440  -6.531   9.935  1.942       -3.558
# 2  3.983  3.060  -2.120 -2.726  10.739  -7.577   7.261 -0.357        0.549
# 3  0.314  1.075  -8.193 -3.999   2.971  -7.096   6.995  0.060       -2.678
# 4 -2.346 -2.404  -0.377 -0.318   0.412  -3.207   6.163  2.134       -1.399
# 5  1.676  0.552  -4.159 -3.315   2.308  -6.315   6.690  0.322       -2.014
# 6  2.060  1.757  -4.422 -5.300   0.441  -3.336   8.363 -1.103       -2.406
# 7  1.575 -1.058  -3.600 -5.432 -10.645  -1.416   7.634  0.743       -2.870
# 8  0.363  1.204  -8.586 -8.981  -6.774 -10.378   9.637  1.598       -3.038
# 9 -1.246 -2.443  -4.127 -4.031  -0.146   2.504  12.789 -0.768       -2.734
#
#      FG%   3PT%    FT%   AST%   FG3A%  PTS/FGA  FG3M/FGM  FTA/FGA   TRU%  \
# 0 -2.578 -4.088 -0.210 -7.600   6.618    0.199     4.966   11.902 -1.140
# 1  0.024 -0.338  0.886 -6.621   7.676    2.249     7.286    8.501  1.226
# 2 -2.995 -1.712 -3.337  0.634  12.681   -0.621    14.171    8.176 -1.546
# 3 -2.741  0.220 -1.257 -6.663   8.883   -1.061    12.198    2.591 -1.358
# 4  0.703  0.998  0.586 -0.691  10.008    2.527    10.331    5.257  1.917
# 5 -1.016 -2.916 -0.250 -3.156   5.379    0.341     3.356    5.834 -0.280
# 6 -3.874 -2.893  2.291 -0.094   5.567   -0.630     6.645    9.904 -1.696
# 7 -0.670  0.588  1.964 -1.333  11.235    2.422    12.644    7.975  1.531
# 8 -0.813 -0.722  1.132 -9.150   0.762    0.151     0.855    3.744 -0.241
# 9 -1.186  0.350  1.331 -1.153   3.419    1.097     5.026    8.632  0.185
#
#    AST_TOV
# 0   -8.073
# 1   -0.373
# 2    5.905
# 3   -1.181
# 4    2.924
# 5    2.301
# 6   -1.123
# 7   -2.215
# 8    1.999
# 9   -6.468

# %%
fig = go.Figure()
for col in comp_change_df.columns[1:]:
    fig.add_trace(go.Scatter(x=comp_change_df['Season_start_year'],
                             y=comp_change_df[col], name=col))
    
fig.show()
